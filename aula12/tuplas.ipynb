# %% [markdown]
# paises = "Brasil", "Paraguai", "uruguai", "mexico"
# pais = paises[0]
# print(pais)
#
# fatia = paises[1:3]
# print(fatia)

# %%
paises = "Brasil", "Paraguai", "uruguai", "mexico"
pais = paises[0]
print(pais)

fatia = paises[1:3]
print(fatia)
# Out:
# Brasil
# ('Paraguai', 'uruguai')

# %%
lista_carros = ["gol", "corolla", "ranger", "kadett", "fusca", "clio"]
tupla_carros = tuple(lista_carros)
print(f"tupla carros: {tupla_carros}")
# Out:
# tupla_carros: ('gol', 'corolla', 'ranger', 'kadett', 'fusca', 'clio')

# %%
tupla_carros = ["gol", "corolla", "ranger", "kadett", "fusca", "clio"]
lista_carros_carros = list(lista_carros)
print(f"lista carros: {tupla_carros}")
# Out:
# lista carros: ['gol', 'corolla', 'ranger', 'kadett', 'fusca', 'clio']
