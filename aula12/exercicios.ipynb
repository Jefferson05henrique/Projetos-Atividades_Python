# %%
numeros = 10, 20, 30, 40
print(numeros[1])
# Out:
# 20

# %%
numeracao = (111, 100, 93, 78, 50)
nome = ("Dandara", "Jorge", "Levi", "Petros", "Zacaria")

print(f"{numeracao[2]} e do {nome[3]}")
# Out:
# 93 e do Petros

# %%
# num = (5,10, 15, 20)
# list_num = list(num)
# list_num = [25]
# tupla_num = tuple(num)

# print(num)


num = (5, 10, 15, 20)
list_num = list(num)
list_num.append(25)
tupla_num = tuple(list_num)

print(tupla_num)
# Out:
# (5, 10, 15, 20, 25)
