# %%
livroUm = {
    "titulo": "senhor dos aneis",
    "autor": "seu zé",
    "ano": 1950
}

livroDois = {
    "titulo": "mount & blade",
    "autor": "seu lima",
    "ano": 2010
}

livroTres = {
    "titulo": "hora de aventura",
    "autor": "seu pingo",
    "ano": 1980
}

conjunto = [livroUm, livroDois, livroTres]

for livro in conjunto:
    print(f"Na nossa biblioteca temos os livros: {livro['titulo']}, escrito por {livro['autor']}, no ano de {livro['ano']}")
# Out:
# Na nossa biblioteca temos os livros: senhor dos aneis, escrito por seu zé, no ano de 1950
# Na nossa biblioteca temos os livros: mount & blade, escrito por seu lima, no ano de 2010
# Na nossa biblioteca temos os livros: hora de aventura, escrito por seu pingo, no ano de 1980
