# %%
produtos = {
    "mouse":98.55,
    "teclado":30.00,
    "monitor":180.90
}

print(f"esses são nossos produtos {produtos}")

del produtos["teclado"]

print(produtos)
# Out:
# esses são nossos produtos {'mouse': 98.55, 'teclado': 30.0, 'monitor': 180.9}
# {'mouse': 98.55, 'monitor': 180.9}

# %%
aluno = {
    "nome":"jairo",
    "idade": 26,
    "curso": "coach"
}

aluno["nota"] = 10

print(f"temos um aluno assim: seu nome é {aluno['nome']}, ele tem {aluno['idade']}, cursa {aluno['curso']} e tem como média nota {aluno['nota']}")
# Out:
# temos um aluno assim: seu nome é jairo, ele tem 26, cursa coach e tem como média nota 10

# %%
produtos = {
    "mouse":98.55,
    "teclado":30.00,
    "monitor":180.90
}

print(f"o preço do nosso primeiro produto é {produtos['mouse']}")
# Out:
# o preço do nosso primeiro produto é 98.55
