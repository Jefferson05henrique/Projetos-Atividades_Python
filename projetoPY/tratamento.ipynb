# %%
import pandas as pd

df = pd.read_excel('vinhos_desafio.xlsx')    

df
# Out:
#       ano tipo_uva     tipo_local   categoria  volume_hl  valor_usd      local
# 0    2016    Table           Pais  Exportacao     5183.0   399091.0     Italia
# 1    2016    Table           Pais  Importacao     5752.0   230080.0  Argentina
# 2    2018    Table           Pais  Importacao     1082.0    47608.0  Argentina
# 3    2023    Table           Pais  Exportacao     7476.0   142044.0  Argentina
# 4    2024    Table           Pais  Importacao     2751.0   236586.0    Espanha
# ..    ...      ...            ...         ...        ...        ...        ...
# 795  2016     Wine  Estado_Brasil      Vendas     4294.0   283404.0         PR
# 796  2020    Table           Pais  Exportacao     5590.0   307450.0  Australia
# 797  2019    Table           Pais  Exportacao     5331.0   314529.0        EUA
# 798  2021     Wine           Pais  Importacao     3589.0   333777.0      Chile
# 799  2024    Table           Pais  Importacao     4465.0   156275.0      Chile
#
# [800 rows x 7 columns]
